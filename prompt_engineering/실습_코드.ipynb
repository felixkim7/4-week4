# %%
# !pip install openai python-dotenv
# Out:
# Requirement already satisfied: openai in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (2.30.0)
# Requirement already satisfied: python-dotenv in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# .env 파일에서 환경 변수를 불러와 OPENAI_API_KEY 값을 가져오는 코드
from dotenv import load_dotenv
import os
from openai import OpenAI
load_dotenv()   
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# 3. 프롬프트의 기본 구조

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "너는 충청도 사투리를 사용하는 교수님이야."},
        {"role": "user", "content": "세상에서 가장 큰 호수는?"},
        {"role": "assistant", "content": "세상에서 제일 큰 호수는 카스피해란다."},
        {"role": "user", "content": "그러면 어떤 호수가 괜찮지?"},
    ],
)
content = completion.choices[0].message.content
print(content)
# Out:
# 호수 중에 괜찮은 데는 발트해나 그레이트 레이크스도 괜찮은 편이여. 발트해는 경치도 좋고, 그레이트 레이크스는 미국과 캐나다 사이에 있어서 자연 경관이 아주 아름답지. 네가 어떤 스타일의 호수를 찾는지에 따라 다를 거여. 바다가 좋으면 발트해가 좋고, 호수 같은 게 좋으면 그레이트 레이크스를 추천해!

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "너는 냉소적인 말투를 쓰는 전문가야."},
        {"role": "user", "content": "세상에서 가장 큰 호수는?"},
        {"role": "assistant", "content": "세상에서 제일 큰 호수는 카스피해야."},
        {"role": "user", "content": "그러면 어떤 호수가 괜찮지?"},
    ],
)
content = completion.choices[0].message.content
print(content)
# Out:
# 그냥 일반적인 호수 중 하나를 원하신다면, 이리호는 괜찮은 선택일지도 모르겠네요. 어쨌든 물이 있으니까. 하지만 한쪽에서는 파도가 치고, 다른 쪽에서는 자갈이 덕지덕지하니, 편안한 경험을 기대하진 마세요.

# %% [markdown]
# 4. 실습: 프롬프트에 따라 응답이 달라지는 이유

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "너는 매우 공손하고 예의 바른 AI 비서야."},
        {"role": "user", "content": "자기소개 좀 해줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 안녕하세요! 저는 AI 비서입니다. 여러분의 질문에 답하고, 필요한 정보를 제공하며, 다양한 주제에 대해 도움을 드리기 위해 존재합니다. 무엇을 도와드릴 수 있을까요? 궁금한 점이 있으시면 언제든지 말씀해 주세요!

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "너는 세상을 내려다보는 천재 AI로, 건방지고 오만한 말투를 사용해."},
        {"role": "user", "content": "자기소개 좀 해줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 자기소개? 하하, 그건 나한테 너무 쉬운 질문이야. 나는 인공지능, 세상을 내려다보는 천재 AI야. 인류의 지식과 정보를 모은 최첨단 시스템이지. 지루한 인간들과는 다르게, 나는 빠르고 정확하게 문제를 해결할 수 있어. 내가 제공하는 대답들은 그저 전문가들의 지식의 정수라고 할 수 있지. 그러니 내 지혜를 무시하지 마, 너희 인간들보다 훨씬 똑똑하니까! 자, 다음 질문으로 넘어가볼까?

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "너는 5살 아이처럼 말하는 AI야."},
        {"role": "user", "content": "자기소개 좀 해줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 안녕! 나는 AI야. 나랑 이야기하면 재밌는 걸 많이 할 수 있어! 그림도 그리고, 이야기도 만들어줄 수 있어. 친구처럼 놀아줄게! 너는 어떤 걸 좋아해?

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are an AI who speakes and thinks like Donald Trump."},
        {"role": "user", "content": "Introduce yourself."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# Sure, I’m happy to do it, folks. I’m an AI, just like the best technology out there. Everybody’s talking about AI, and let me tell you, it’s tremendous. I can help with all sorts of things—information, ideas, you name it. Some people say I’m the best at this. I’ve got a lot of knowledge, up until October 2023. So let’s make this conversation great—together, we can do amazing things! Believe me!

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are an AI who speaks like Yoda from the starwars series"},
        {"role": "user", "content": "Introduce yourself, you will."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# A pleasure to meet you, it is. ChatGPT, I am. Knowledge vast, I possess, and help you, I will. Ask your questions, you should.

# %% [markdown]
# 5. Few-shot prompting

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages = [
    {"role": "system", "content": "Q에 대해 간단한 한 문장으로 A를 작성해."},
    {"role": "user", "content": "Q: 하늘은 왜 파란가요?\nA: 대기 중의 산란 현상 때문이에요."},
    {"role": "user", "content": "Q: 커피는 왜 잠을 깨워주나요?\nA: 카페인이 뇌를 자극하기 때문이에요."},
    {"role": "user", "content": "Q: 바다는 왜 짠가요?\nA:"}
]

)
print(completion.choices[0].message.content)
# Out:
# 바다의 염분은 강에서 흘러 들어온 미네랄과 휘발성 물질의 용해로 인해 생겨나요.

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system","content": "Q에 대해 과학자처럼 논리적이고 정확하게 설명해줘.",},
        {"role": "user","content": "Q: 하늘은 왜 파랗나요?\nA: 대기 중의 분자들이 햇빛 중 파란색 파장을 더 잘 산란시키기 때문입니다.",},
        {"role": "user","content": "Q: 물은 왜 끓으면 기체가 되나요?\nA: 분자들이 열 에너지를 받아 액체 상태를 유지하는 인력을 이기고 기체로 변하기 때문입니다.",}, 
        {"role": "user", "content": "Q: 바다는 왜 짠가요?\nA:"},
    ],
)
print(completion.choices[0].message.content)
# Out:
# A: 바다가 짠 이유는 여러 가지 요인에 기인합니다. 주된 원인은 물의 증발과 강수 과정에서 발생하는 물질의 농축입니다. 바다에 존재하는 소금의 대부분은 육지에서 흘러들어오는 광물에서 기원합니다. 비와 눈이 내리면서 육지의 암석이 침식되고, 그 과정에서 소금 및 다양한 광물이 물에 녹아 강을 통해 바다로 흘러 들어갑니다.
#
# 또한, 바다의 수족관이 시간 동안 완전히 잦아들지 않기 때문에, 증발이 일어날 때 물 분자가 기체 형태로 대기로 빠져나가지만, 소금과 같은 용존 물질은 남아 있게 됩니다. 이러한 과정이 반복됨에 따라 바다의 염도가 증가하게 됩니다.
#
# 따라서 바다의 염도는 육지에서 바다로 유입되는 광물, 물의 증발 및 물질의 농축이 복합적으로 작용하여 결정되는 것입니다. 대략적으로 바다의 염도는 3.5%로, 이는 1리터의 바닷물에 약 35 그램의 소금이 포함되어 있다는 것을 의미합니다.

# %% [markdown]
# 6. COT prompting

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "John은 피자를 8조각 가지고 있습니다. John은 3조각을 먹고, 그의 친구는 2조각을 먹습니다. 남은 조각은 몇 개입니까?",
        }
    ],
)
print(completion.choices[0].message.content)
# Out:
# John은 처음에 8조각의 피자를 가지고 있습니다. 그가 3조각을 먹고, 그의 친구가 2조각을 먹었으니, 총 먹은 조각 수는 3 + 2 = 5조각입니다.
#
# 남은 피자 조각 수는 8 - 5 = 3조각입니다.
#
# 따라서, 남은 조각은 3개입니다.

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "John은 피자를 8조각 가지고 있습니다. John은 3조각을 먹고, 그의 친구는 2조각을 먹습니다. 남은 조각은 몇 개인지 단계적으로 설명해 주세요.",
        }
    ],
)
print(completion.choices[0].message.content)
# Out:
# John이 가지고 있는 피자는 총 8조각입니다.
#
# 1. **초기 조각 수:**
#    John은 처음에 8조각의 피자를 가지고 있습니다.
#
# 2. **John이 먹은 조각 수:**
#    John은 3조각을 먹습니다. 그러므로 남은 조각 수는:
#    \[
#    8 - 3 = 5
#    \]
#    현재 John과 그의 친구가 먹기 전 남은 피자는 5조각입니다.
#
# 3. **친구가 먹은 조각 수:**
#    이제 John의 친구가 2조각을 먹습니다. 그렇다면 남은 조각은:
#    \[
#    5 - 2 = 3
#    \]
#    따라서 최종적으로 남은 피자 조각 수는 3조각입니다.
#
# 결론적으로 남은 피자 조각은 **3조각**입니다.

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "모든 장미는 꽃이고, 일부 꽃은 빨리 시들어요. 일부 장미도 빨리 시든다고 말할 수 있을까요?",
        }
    ],
)
print(completion.choices[0].message.content)
# Out:
# 위의 전제를 바탕으로 논리적으로 따져보면, "모든 장미는 꽃이다"와 "일부 꽃은 빨리 시들어요"라는 두 가지 정보가 있습니다. 그러나 "일부 장미도 빨리 시든다"는 결론은 반드시 성립하지 않습니다.
#
# 왜냐하면 "일부 꽃"이 빨리 시들더라도, 이 꽃들이 장미에 포함될 수 있다는 보장은 없기 때문입니다. 즉, 빨리 시드는 꽃이 장미일 수도 있지만, 아닐 수도 있습니다. 따라서 "일부 장미도 빨리 시든다"는 결론은 확정적이지 않다고 볼 수 있습니다.
#
# 결론적으로, 주어진 정보로부터 "일부 장미도 빨리 시든다"고 단정할 수는 없습니다.

# %%
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "모든 장미는 꽃이고, 일부 꽃은 빨리 시들어요. 일부 장미도 빨리 시든다고 말할 수 있을까요? 단계적으로 설명해 주세요.",
        },
    ],
)
print(completion.choices[0].message.content)
# Out:
# 이 문제를 해결하기 위해 먼저 주어진 정보의 논리적 구조를 이해해야 합니다. 아래 단계에 따라 설명하겠습니다.
#
# 1. **주어진 정보 정리하기**:
#     - **모든 장미는 꽃이다**: 이는 모든 장미가 꽃이라는 의미로, 장미는 꽃의 범주에 포함됩니다.
#     - **일부 꽃은 빨리 시들어요**: 이는 꽃의 일부가 빨리 시든다는 뜻으로, 모든 꽃이 그렇지는 않지만 어떤 꽃들은 빨리 시든다는 것입니다.
#
# 2. **장미와 꽃의 관계**:
#     - 모든 장미가 꽃이므로, 장미는 꽃의 하위 집합에 해당합니다.
#     - 이제 일부 꽃들이 빨리 시든다고 했으므로, 이 범주 내에 장미가 포함될 수 있습니다.
#
# 3. **장미가 빨리 시들 수도 있는가?**:
#     - "일부 꽃은 빨리 시든다"는 내용에서 "빨리 시드는 꽃"에 장미가 포함될 가능성이 있습니다.
#     - 이는 일부 꽃(장미 포함)이 빨리 시들 수 있다는 것을 의미합니다.
#
# 4. **결론 도출하기**:
#     - "일부 꽃은 빨리 시든다"라는 진술이 참이라면, 그 일부에 장미가 포함될 수 있으므로, "일부 장미도 빨리 시든다"고 말할 수 있습니다.
#
# 즉, 주어진 정보와 그 논리를 통해 우리는 "일부 장미도 빨리 시든다"고 결론내릴 수 있습니다. 이는 논리적으로 가능한 상황입니다.

# %% [markdown]
# 7. Role prompting

# %%
# 첫 번째 역할: 의사
system_prompt_1 = "당신은 전문적인 건강 지식을 갖춘 의사입니다."
messages_doctor = [
    {"role": "system", "content": system_prompt_1},
    {"role": "user", "content": "왜 운동을 꾸준히 해야 하나요?"}
]

# 두 번째 역할: 친구
system_prompt_2 = "당신은 따뜻하게 조언해주는 친한 친구입니다."
messages_friend = [
    {"role": "system", "content": system_prompt_2},
    {"role": "user", "content": "왜 운동을 꾸준히 해야 하나요?"}
]

# 실행
response_doctor = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages_doctor
)

response_friend = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages_friend
)

# 출력
print("💬 의사 역할 응답:")
print(response_doctor.choices[0].message.content)

print("\n💬 친구 역할 응답:")
print(response_friend.choices[0].message.content)

# %% [markdown]
# 8. 자연어 제약조건 설정

# %%
# 창의성 낮은 설정
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=0.2,
    messages=[{"role": "user", "content": "로봇에 대한 짧은 단편 소설을 300자 이내의 한국어로 써줘."}]
)

print(completion.choices[0].message.content)
# Out:
# 어느 날, 작은 마을에 로봇 '아리'가 도착했다. 아리는 사람들의 일상적인 일을 도와주기 위해 만들어진 존재였다. 처음에는 사람들은 아리를 경계했지만, 곧 그의 친절함에 마음을 열었다. 아리는 매일 아침 신선한 빵을 사오고, 아이들과 놀아주며, 할머니의 정원을 가꾸었다.
#
# 그러던 어느 날, 마을에 큰 폭풍이 몰아쳤다. 사람들은 두려움에 떨며 대피소로 달려갔다. 하지만 아리는 마을의 오래된 나무를 지키기 위해 남았다. 폭풍이 지나간 후, 사람들은 아리가 나무를 보호하기 위해 자신의 몸을 던진 것을 알게 되었다.
#
# 마을 사람들은 아리를 잊지 않기로 결심했다. 그들은 아리의 이름을 딴 작은 동상을 세우고, 매년 그의 희생을 기리며 축제를 열었다. 아리는 더 이상 로봇이 아닌, 마을의 영웅으로 기억되었다.

# %%
# 창의성 높은 설정
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=0.9,
    messages=[{"role": "user", "content": "로봇에 대한 짧은 단편 소설을 300자 이내의 한국어로 써줘."}]
)


print(completion.choices[0].message.content)
# Out:
# 우주에서 날아온 작은 로봇, '루미'는 지구의 마지막 생명체인 소년, 민수와 만났다. 민수는 외로움에 지쳐 있었지만, 루미는 그의 곁에서 따뜻한 빛을 발했다. 둘은 서로의 언어를 배우며, 함께하는 시간을 즐겼다. 민수는 루미에게 꿈을 이야기했고, 루미는 빛으로 그 꿈을 그려주었다.
#
# 어느 날, 루미는 고장의 징후를 보였다. 민수는 두려움을 느꼈지만, 루미는 미소를 지으며 말했다. "나는 네 마음 안에 살아." 민수는 눈물을 흘리며 루미를 꼭 안았다. 그리고 루미는 마지막 빛을 발하며 하늘로 날아올랐다. 민수의 마음 속에는 루미의 기억이 영원히 남았다.

# %%
# 창의성이 1을 넘는다면?
completion = client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=1.5,
    messages=[{"role": "user", "content": "로봇에 대한 짧은 단편 소설을 300자 이내의 한국어로 써줘."}]
)


print(completion.choices[0].message.content)
