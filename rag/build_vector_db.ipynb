# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: openai in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from -r ../requirements.txt (line 5)) (2.30.0)
# Requirement already satisfied: python-dotenv in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from -r ../requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: huggingface-hub in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from -r ../requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: numpy in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from -r ../requirements.txt (line 8)) (2.4.3)
# Requirement already satisfied: pandas in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from -r ../requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: datasets in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from -r ../requirements.txt (line 10)) (4.8.4)
# Requirement already satisfied: chromadb in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from -r ../requirements.txt (line 11)) (1.5.5)
# Collecting langchain (from -r ../requirements.txt (line 12))
#   Downloading langchain-1.2.14-py3-none-any.whl.metadata (5.8 kB)
# Collecting tiktoken (from -r ../requirements.txt (line 13))
#   Using cached tiktoken-0.12.0-cp314-cp314-win_amd64.whl.metadata (6.9 kB)
# Collecting unstructured (from -r ../requirements.txt (line 15))
#   Using cached unstructured-0.18.32-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (2.12.5)
# Requirement already satisfied: sniffio in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from openai->-r ../requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 5)) (3.11)
# Requirement already satisfied: certifi in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 5)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 5)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: packaging>=20.9 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: typer in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (0.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pandas->-r ../requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from pandas->-r ../requirements.txt (line 9)) (2025.3)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (2.33.0)
# Requirement already satisfied: xxhash in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (3.13.3)
# Requirement already satisfied: build>=1.0.3 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.4.2)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (0.42.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (9.1.4)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (3.11.7)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (4.26.0)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain->-r ../requirements.txt (line 12))
#   Downloading langchain_core-1.2.23-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.1 (from langchain->-r ../requirements.txt (line 12))
#   Downloading langgraph-1.1.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain->-r ../requirements.txt (line 12))
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain->-r ../requirements.txt (line 12))
#   Downloading langsmith-0.7.23-py3-none-any.whl.metadata (15 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain->-r ../requirements.txt (line 12))
#   Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain->-r ../requirements.txt (line 12))
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.1->langchain->-r ../requirements.txt (line 12))
#   Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph<1.2.0,>=1.1.1->langchain->-r ../requirements.txt (line 12))
#   Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.1->langchain->-r ../requirements.txt (line 12))
#   Using cached langgraph_sdk-0.3.12-py3-none-any.whl.metadata (1.6 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain->-r ../requirements.txt (line 12))
#   Using cached ormsgpack-1.12.2-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain->-r ../requirements.txt (line 12))
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain->-r ../requirements.txt (line 12))
#   Using cached zstandard-0.25.0-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from tiktoken->-r ../requirements.txt (line 13)) (2026.2.28)
# Requirement already satisfied: charset-normalizer in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (3.4.6)
# Collecting filetype (from unstructured->-r ../requirements.txt (line 15))
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured->-r ../requirements.txt (line 15))
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured->-r ../requirements.txt (line 15))
#   Using cached lxml-6.0.2-cp314-cp314-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: nltk in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (3.9.4)
# Collecting beautifulsoup4 (from unstructured->-r ../requirements.txt (line 15))
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting emoji (from unstructured->-r ../requirements.txt (line 15))
#   Using cached emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured->-r ../requirements.txt (line 15))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured->-r ../requirements.txt (line 15))
#   Using cached python_iso639-2026.1.31-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured->-r ../requirements.txt (line 15))
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting rapidfuzz (from unstructured->-r ../requirements.txt (line 15))
#   Using cached rapidfuzz-3.14.3-cp314-cp314-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured->-r ../requirements.txt (line 15))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured->-r ../requirements.txt (line 15))
#   Using cached unstructured_client-0.42.12-py3-none-any.whl.metadata (23 kB)
# Collecting wrapt (from unstructured->-r ../requirements.txt (line 15))
#   Using cached wrapt-2.1.2-cp314-cp314-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: psutil in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (7.2.2)
# Collecting python-oxmsg (from unstructured->-r ../requirements.txt (line 15))
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured->-r ../requirements.txt (line 15))
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting numba (from unstructured->-r ../requirements.txt (line 15))
#   Downloading numba-0.65.0-cp314-cp314-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (1.23.0)
# Requirement already satisfied: pyproject_hooks in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from build>=1.0.3->chromadb->-r ../requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from build>=1.0.3->chromadb->-r ../requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 11)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 11)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 11)) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (25.12.19)
# Requirement already satisfied: protobuf in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (6.33.6)
# Requirement already satisfied: sympy in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (0.61b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r ../requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: click>=8.2.1 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from typer->huggingface-hub->-r ../requirements.txt (line 7)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from typer->huggingface-hub->-r ../requirements.txt (line 7)) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from typer->huggingface-hub->-r ../requirements.txt (line 7)) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (16.0)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->unstructured->-r ../requirements.txt (line 15))
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured->-r ../requirements.txt (line 15))
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured->-r ../requirements.txt (line 15))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured->-r ../requirements.txt (line 15))
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting webencodings (from html5lib->unstructured->-r ../requirements.txt (line 15))
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: joblib in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from nltk->unstructured->-r ../requirements.txt (line 15)) (1.5.3)
# Collecting llvmlite<0.48,>=0.47.0dev0 (from numba->unstructured->-r ../requirements.txt (line 15))
#   Downloading llvmlite-0.47.0-cp314-cp314-win_amd64.whl.metadata (5.1 kB)
# Collecting olefile (from python-oxmsg->unstructured->-r ../requirements.txt (line 15))
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\minso\anaconda3\envs\session4\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (1.3.0)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured->-r ../requirements.txt (line 15))
#   Using cached aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured->-r ../requirements.txt (line 15))
#   Using cached cryptography-46.0.6-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting pypdf>=6.2.0 (from unstructured-client->unstructured->-r ../requirements.txt (line 15))
#   Using cached pypdf-6.9.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting pypdfium2>=5.0.0 (from unstructured-client->unstructured->-r ../requirements.txt (line 15))
#   Using cached pypdfium2-5.6.0-py3-none-win_amd64.whl.metadata (68 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.1->unstructured-client->unstructured->-r ../requirements.txt (line 15))
#   Using cached cffi-2.0.0-cp314-cp314-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured->-r ../requirements.txt (line 15))
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading langchain-1.2.14-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.2.23-py3-none-any.whl (506 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.1.4-py3-none-any.whl (168 kB)
# Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.12-py3-none-any.whl (95 kB)
# Downloading langsmith-0.7.23-py3-none-any.whl (362 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Using cached tiktoken-0.12.0-cp314-cp314-win_amd64.whl (921 kB)
# Using cached unstructured-0.18.32-py3-none-any.whl (1.8 MB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached ormsgpack-1.12.2-cp314-cp314-win_amd64.whl (117 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached zstandard-0.25.0-cp314-cp314-win_amd64.whl (516 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached emoji-2.15.0-py3-none-any.whl (608 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Using cached lxml-6.0.2-cp314-cp314-win_amd64.whl (4.1 MB)
# Downloading numba-0.65.0-cp314-cp314-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.8 MB 3.4 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.8 MB 3.7 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.8 MB 1.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.8 MB 1.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 1.6 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.8 MB 1.5 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 1.3 MB/s  0:00:02
# Downloading llvmlite-0.47.0-cp314-cp314-win_amd64.whl (39.2 MB)
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.2 MB 500.0 kB/s eta 0:01:18
#     --------------------------------------- 0.8/39.2 MB 726.8 kB/s eta 0:00:53
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.0/39.2 MB 872.2 kB/s eta 0:00:44
#    - -------------------------------------- 1.3/39.2 MB 360.8 kB/s eta 0:01:45
#    - -------------------------------------- 1.3/39.2 MB 360.8 kB/s eta 0:01:45
#    - -------------------------------------- 1.3/39.2 MB 360.8 kB/s eta 0:01:45
#    - -------------------------------------- 1.3/39.2 MB 360.8 kB/s eta 0:01:45
#    - -------------------------------------- 1.6/39.2 MB 336.7 kB/s eta 0:01:52
#    - -------------------------------------- 1.6/39.2 MB 336.7 kB/s eta 0:01:52
#    - -------------------------------------- 1.8/39.2 MB 376.9 kB/s eta 0:01:40
#    - -------------------------------------- 1.8/39.2 MB 376.9 kB/s eta 0:01:40
#    - -------------------------------------- 1.8/39.2 MB 376.9 kB/s eta 0:01:40
#    - -------------------------------------- 1.8/39.2 MB 376.9 kB/s eta 0:01:40
#    -- ------------------------------------- 2.4/39.2 MB 408.1 kB/s eta 0:01:31
#    -- ------------------------------------- 2.6/39.2 MB 452.0 kB/s eta 0:01:21
#    -- ------------------------------------- 2.6/39.2 MB 452.0 kB/s eta 0:01:21
#    -- ------------------------------------- 2.6/39.2 MB 452.0 kB/s eta 0:01:21
#    -- ------------------------------------- 2.6/39.2 MB 452.0 kB/s eta 0:01:21
#    -- ------------------------------------- 2.9/39.2 MB 431.4 kB/s eta 0:01:25
#    -- ------------------------------------- 2.9/39.2 MB 431.4 kB/s eta 0:01:25
kB/s eta 0:00:14
#    ------------------------------- -------- 30.4/39.2 MB 655.5 kB/s eta 0:00:14
#    ------------------------------- -------- 30.9/39.2 MB 655.7 kB/s eta 0:00:13
#    ------------------------------- -------- 31.2/39.2 MB 660.7 kB/s eta 0:00:13
#    ------------------------------- -------- 31.2/39.2 MB 660.7 kB/s eta 0:00:13
#    -------------------------------- ------- 31.7/39.2 MB 668.3 kB/s eta 0:00:12
#    --------------------------------- ------ 33.0/39.2 MB 746.9 kB/s eta 0:00:09
#    ---------------------------------- ----- 33.6/39.2 MB 760.6 kB/s eta 0:00:08
#    ---------------------------------- ----- 33.8/39.2 MB 765.5 kB/s eta 0:00:07
#    ---------------------------------- ----- 33.8/39.2 MB 765.5 kB/s eta 0:00:07
#    ---------------------------------- ----- 34.1/39.2 MB 765.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 34.1/39.2 MB 765.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 34.1/39.2 MB 765.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 34.1/39.2 MB 765.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 34.1/39.2 MB 765.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 34.1/39.2 MB 765.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 34.1/39.2 MB 765.7 kB/s eta 0:00:07
#    ----------------------------------- ---- 34.3/39.2 MB 735.0 kB/s eta 0:00:07
#    ------------------------------------ --- 35.7/39.2 MB 760.9 kB/s eta 0:00:05
#    ------------------------------------- -- 37.0/39.2 MB 775.1 kB/s eta 0:00:03
#    ---------------------------------------  38.3/39.2 MB 813.9 kB/s eta 0:00:02
#    ---------------------------------------- 39.2/39.2 MB 838.5 kB/s  0:00:57
# Downloading python_iso639-2026.1.31-py3-none-any.whl (167 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading rapidfuzz-3.14.3-cp314-cp314-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 6.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 611.9 kB/s  0:00:02
# Downloading unstructured_client-0.42.12-py3-none-any.whl (220 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading cryptography-46.0.6-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.5 MB ? eta -:--:--
#    ------------ --------------------------- 1.0/3.5 MB 3.6 MB/s eta 0:00:01
#    --------------------- ------------------ 1.8/3.5 MB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 2.9/3.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 1.3 MB/s  0:00:02
# Using cached cffi-2.0.0-cp314-cp314-win_amd64.whl (185 kB)
# Downloading pypdf-6.9.2-py3-none-any.whl (333 kB)
# Downloading pypdfium2-5.6.0-py3-none-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.7 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.7 MB 1.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.1/3.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.1/3.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------- -------------- 2.4/3.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.7 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 3.1/3.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 1.0 MB/s  0:00:03
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading wrapt-2.1.2-cp314-cp314-win_amd64.whl (60 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993364 sha256=8f18ad4b9944e448bc7656ac196fea87d185fb076dbc6368425d3997e8b7237c
#   Stored in directory: c:\users\minso\appdata\local\pip\cache\wheels\13\60\5a\f2012969b3f7413b62b7b7063d6c9b45c93004a978cbe8ea2f
# Successfully built langdetect
# Installing collected packages: webencodings, filetype, zstandard, wrapt, uuid-utils, soupsieve, rapidfuzz, python-magic, python-iso639, pypdfium2, pypdf, pycparser, ormsgpack, olefile, mypy-extensions, marshmallow, lxml, llvmlite, langdetect, jsonpointer, html5lib, emoji, backoff, aiofiles, typing-inspect, tiktoken, requests-toolbelt, python-oxmsg, numba, jsonpatch, cffi, beautifulsoup4, langsmith, langgraph-sdk, dataclasses-json, cryptography, unstructured-client, langchain-core, unstructured, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    --- ------------------------------------  4/43 [uuid-utils]
#    ----- ----------------------------------  6/43 [rapidfuzz]
#    -------- -------------------------------  9/43 [pypdfium2]
#    --------- ------------------------------ 10/43 [pypdf]
#    --------- ------------------------------ 10/43 [pypdf]
#    ----------- ---------------------------- 12/43 [ormsgpack]
#    -------------- ------------------------- 16/43 [lxml]
#    -------------- ------------------------- 16/43 [lxml]
#    --------------- ------------------------ 17/43 [llvmlite]
#    --------------- ------------------------ 17/43 [llvmlite]
#    --------------- ------------------------ 17/43 [llvmlite]
#    ---------------- ----------------------- 18/43 [langdetect]
#    ------------------ --------------------- 20/43 [html5lib]
#    ---------------------- ----------------- 24/43 [typing-inspect]
#    ------------------------- -------------- 27/43 [python-oxmsg]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    -------------------------- ------------- 28/43 [numba]
#    --------------------------- ------------ 30/43 [cffi]
#    ---------------------------- ----------- 31/43 [beautifulsoup4]
#    ----------------------------- ---------- 32/43 [langsmith]
#    ----------------------------- ---------- 32/43 [langsmith]
#    ------------------------------ --------- 33/43 [langgraph-sdk]
#    -------------------------------- ------- 35/43 [cryptography]
#    -------------------------------- ------- 35/43 [cryptography]
#    --------------------------------- ------ 36/43 [unstructured-client]
#    --------------------------------- ------ 36/43 [unstructured-client]
#    --------------------------------- ------ 36/43 [unstructured-client]
#    ---------------------------------- ----- 37/43 [langchain-core]
#    ---------------------------------- ----- 37/43 [langchain-core]
#    ---------------------------------- ----- 37/43 [langchain-core]
#    ---------------------------------- ----- 37/43 [langchain-core]
#    ---------------------------------- ----- 37/43 [langchain-core]
#    ----------------------------------- ---- 38/43 [unstructured]
#    ----------------------------------- ---- 38/43 [unstructured]
#    ----------------------------------- ---- 38/43 [unstructured]
#    ----------------------------------- ---- 38/43 [unstructured]
#    ----------------------------------- ---- 38/43 [unstructured]
#    ------------------------------------- -- 40/43 [langgraph-prebuilt]
#    -------------------------------------- - 41/43 [langgraph]
#    ---------------------------------------  42/43 [langchain]
#    ---------------------------------------- 43/43 [langchain]
#
# Successfully installed aiofiles-25.1.0 backoff-2.2.1 beautifulsoup4-4.14.3 cffi-2.0.0 cryptography-46.0.6 dataclasses-json-0.6.7 emoji-2.15.0 filetype-1.2.0 html5lib-1.1 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.2.14 langchain-core-1.2.23 langdetect-1.0.9 langgraph-1.1.4 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.12 langsmith-0.7.23 llvmlite-0.47.0 lxml-6.0.2 marshmallow-3.26.2 mypy-extensions-1.1.0 numba-0.65.0 olefile-0.47 ormsgpack-1.12.2 pycparser-3.0 pypdf-6.9.2 pypdfium2-5.6.0 python-iso639-2026.1.31 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.14.3 requests-toolbelt-1.0.0 soupsieve-2.8.3 tiktoken-0.12.0 typing-inspect-0.9.0 unstructured-0.18.32 unstructured-client-0.42.12 uuid-utils-0.14.1 webencodings-0.5.1 wrapt-2.1.2 zstandard-0.25.0

# %%
def init_db(db_path="./chroma_db"):
    dbclient = chromadb.PersistentClient(path=db_path)
    try:
        dbclient.delete_collection(name="rag_collection")
    except:
        pass 
        
    collection = dbclient.create_collection(name="rag_collection")
    return dbclient, collection

# %%
import os  # os를 가져와 파일 시스템 접근, 환경 변수 읽을 수 있음
from openai import OpenAI  # OpenAI의 api 사용 가능
import chromadb  # chromadb 라이브러리 쓸 수 있게 해줌
from chromadb.config import (
    Settings,
)  # Settings 클래스는 DB의 구성 옵션을 설정하는데 사용
from dotenv import load_dotenv  # 환경 변수를 로드하기 위함

# %% [markdown]
# 1. 환경 변수 Load해서 api_key 가져오고 OpenAI 클라이언트(객체) 초기화

# %%
load_dotenv() 
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %% [markdown]
# 2. DB 초기화 함수 (매 실행 시 DB 폴더를 삭제 후 새로 생성)

# %%
# DB 초기화 함수
def init_db(db_path="./chroma_db"): # 현재 디렉토리 내의 chroma_db폴더 설정
    dbclient = chromadb.PersistentClient(path=db_path) # 지정 경로로 향하는 dbClient 생성
    # rag_collection이라는 데이터 컬렉션(모음집) 만듦
    # get_or_create옵션은 만약 해당 이름 컬렉션이 이미 존재하면 기존 컬렉션 쓰고 아님 만들고
    collection = dbclient.create_collection(name="rag_collection", get_or_create=True)
    return dbclient, collection

# %% [markdown]
# 3. 텍스트 로딩 함수

# %%
# 텍스트 로딩 함수 
def load_text_files(folder_path):
    docs=[] # 텍스트 파일의 (파일명, 내용) 튜플들을 저장할 빈 리스트 생성
    for filename in os.listdir(folder_path): 
		    # 현재 폴더 경로와 파일 이름을 결합하여 파일의 전체 경로를 생성
        file_path = os.path.join(folder_path, filename) 
        if file_path.endswith(".txt"): # .txt 파일들을 처리하게 함
            with open(file_path, "r", encoding="utf-8") as f: # 읽기모드로 열고 인코딩
                text = f.read() # 파일 전체 내용을 읽어서 문자열로 저장
                docs.append((filename, text)) # (파일명, 내용) 튜플을 docs 리스트에 추가
    return docs # 모든 텍스트 파일의 (파일명, 내용) 튜플 리스트를 반환

# %% [markdown]
# 4. 주어진 text를 임베딩 벡터로 변환하는 함수

# %%
# 주어진 text를 임베딩 벡터로 변환하는 함수 
def get_embedding(text, model="text-embedding-3-large"):
		# 여기서 client는 앞서 초기화한 OpenAI 클라이언트
    response = client.embeddings.create(input=[text], model=model)
    embedding = response.data[0].embedding # 응답 객체의 data 리스트에서 embedding 필드 추출
    return embedding

# %% [markdown]
# 5. 원천 데이터 청크 단위로 나누고 overlap 사이즈 조절하는 함수

# %%
# 원천 데이터 청크 단위로 나누고 overlap 사이즈 조절하는 함수
def chunk_text(text, chunk_size=400, chunk_overlap=50):
    chunks = [] # 분할된 텍스트 청크들을 저장할 리스트
    start = 0 # 청크를 시작할 위치를 나타내는 인덱스
    while start < len(text):
        end = start + chunk_size
        chunk = text[start:end] # 텍스트에서 start부터 end까지 부분 문자열을 추출
        chunks.append(chunk) # 추출한 청크를 리스트에 추가
        start = end - chunk_overlap # overlap 적용

        if start < 0: # 음수가 될 수 있으니 예외 처리
            start = 0

        if start >= len(text): # 종료 시그널
            break

    return chunks # 모든 청크가 저장된 리스트를 반환

# %% [markdown]
# 6. 문서로드 -> 청크 나누고 -> 임베딩 생성 후 DB 삽입

# %%
# 문서로드 -> 청크 나누고 -> 임베딩 생성 후 DB 삽입
if __name__ == "__main__":
    # db 초기화
    dbclient, collection = init_db("./chroma_db")

    folder_path = "./source_data" # 데이터 가져다 쓸 경로 지정
    docs = load_text_files(folder_path) # 처리할 문서 데이터 메모리로 불러오기

    doc_id = 0
    for filename, text in docs: 
        chunks = chunk_text(text, chunk_size=400, chunk_overlap=50) # chunking
        for idx, chunk in enumerate(chunks): # 각 청크와 해당 청크의 인덱스 가져옴
            doc_id += 1 # 인덱스 하나씩 증가 시키면서
            embedding = get_embedding(chunk) # 각 청크 임베딩 벡터 생성
            # vectorDB에 다음 정보 추가
            collection.add(
                documents=[chunk], # 실제 청크 text
                embeddings=[embedding], # 생성된 임베딩 벡터
                metadatas=[{"filename": filename, "chunk_index": idx}], # 파일 이름과 청크 인덱스를 포함하는 메타데이터
                ids=[str(doc_id)] # 각 청크의 Unique한 id 저장
                # 이 고유 id를 통해 db에서 업데이트, 삭제등의 작업 가능 
            )
            
    print("모든 문서 벡터DB에 저장 완료")
# Out:
# 모든 문서 벡터DB에 저장 완료
