# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: openai in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied: python-dotenv in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: huggingface-hub in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 7)) (0.35.1)
# Requirement already satisfied: numpy in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 8)) (2.2.6)
# Requirement already satisfied: pandas in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 9)) (2.3.2)
# Requirement already satisfied: datasets in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 10)) (4.1.1)
# Requirement already satisfied: chromadb in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: langchain in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: tiktoken in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 13)) (0.11.0)
# Requirement already satisfied: unstructured in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from -r ../requirements.txt (line 15)) (0.18.15)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (2.11.9)
# Requirement already satisfied: sniffio in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from openai->-r ../requirements.txt (line 5)) (4.14.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from anyio<5,>=3.5.0->openai->-r ../requirements.txt (line 5)) (3.10)
# Requirement already satisfied: certifi in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 5)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r ../requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 5)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r ../requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: filelock in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (2025.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: requests in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub->-r ../requirements.txt (line 7)) (2.32.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from pandas->-r ../requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from pandas->-r ../requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from pandas->-r ../requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: xxhash in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from datasets->-r ../requirements.txt (line 10)) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (3.12.15)
# Requirement already satisfied: build>=1.0.3 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (0.37.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (1.75.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (9.1.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (3.11.3)
# Requirement already satisfied: rich>=10.11.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from chromadb->-r ../requirements.txt (line 11)) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r ../requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r ../requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from requests->huggingface-hub->-r ../requirements.txt (line 7)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from requests->huggingface-hub->-r ../requirements.txt (line 7)) (2.5.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langchain->-r ../requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langchain->-r ../requirements.txt (line 12)) (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain->-r ../requirements.txt (line 12)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain->-r ../requirements.txt (line 12)) (0.4.31)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain->-r ../requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 12)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 12)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 12)) (0.2.12)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->-r ../requirements.txt (line 12)) (1.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain->-r ../requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain->-r ../requirements.txt (line 12)) (0.25.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from tiktoken->-r ../requirements.txt (line 13)) (2025.9.18)
# Requirement already satisfied: filetype in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (0.4.27)
# Requirement already satisfied: lxml in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (6.0.2)
# Requirement already satisfied: nltk in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (4.13.5)
# Requirement already satisfied: emoji in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (2.15.0)
# Requirement already satisfied: dataclasses-json in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (2025.2.18)
# Requirement already satisfied: langdetect in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (3.14.1)
# Requirement already satisfied: unstructured-client in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (0.42.3)
# Requirement already satisfied: wrapt in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (1.17.3)
# Requirement already satisfied: psutil in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (7.1.0)
# Requirement already satisfied: python-oxmsg in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (0.0.2)
# Requirement already satisfied: html5lib in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured->-r ../requirements.txt (line 15)) (1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->-r ../requirements.txt (line 10)) (1.20.1)
# Requirement already satisfied: pyproject_hooks in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from build>=1.0.3->chromadb->-r ../requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: colorama in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from build>=1.0.3->chromadb->-r ../requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from build>=1.0.3->chromadb->-r ../requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 11)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 11)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from jsonschema>=4.19.0->chromadb->-r ../requirements.txt (line 11)) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r ../requirements.txt (line 11)) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (6.32.1)
# Requirement already satisfied: sympy in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r ../requirements.txt (line 11)) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from rich>=10.11.0->chromadb->-r ../requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r ../requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from typer>=0.9.0->chromadb->-r ../requirements.txt (line 11)) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from typer>=0.9.0->chromadb->-r ../requirements.txt (line 11)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r ../requirements.txt (line 11)) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from beautifulsoup4->unstructured->-r ../requirements.txt (line 15)) (2.8)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (3.5.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from dataclasses-json->unstructured->-r ../requirements.txt (line 15)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from dataclasses-json->unstructured->-r ../requirements.txt (line 15)) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured->-r ../requirements.txt (line 15)) (1.1.0)
# Requirement already satisfied: webencodings in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from html5lib->unstructured->-r ../requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: joblib in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from nltk->unstructured->-r ../requirements.txt (line 15)) (1.5.2)
# Requirement already satisfied: olefile in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from python-oxmsg->unstructured->-r ../requirements.txt (line 15)) (0.47)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r ../requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured-client->unstructured->-r ../requirements.txt (line 15)) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured-client->unstructured->-r ../requirements.txt (line 15)) (46.0.1)
# Requirement already satisfied: pypdf>=4.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from unstructured-client->unstructured->-r ../requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured->-r ../requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\yunji\anaconda3\envs\myenv\lib\site-packages (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured->-r ../requirements.txt (line 15)) (2.23)

# %%
# build_vector_db.ipynb에서 수정
def init_db(db_path="./chroma_db"):
    dbclient = chromadb.PersistentClient(path=db_path)
    
    # 만약 기존에 컬렉션이 있으면 지우고 새로 만듦
    try:
        dbclient.delete_collection(name="rag_collection")
    except:
        pass # 없으면 그냥 넘어감
        
    collection = dbclient.create_collection(name="rag_collection")
    return dbclient, collection

# %%
import os  # os를 가져와 파일 시스템 접근, 환경 변수 읽을 수 있음
from openai import OpenAI  # OpenAI의 api 사용 가능
import chromadb  # chromadb 라이브러리 쓸 수 있게 해줌
from chromadb.config import (
    Settings,
)  # Settings 클래스는 DB의 구성 옵션을 설정하는데 사용
from dotenv import load_dotenv  # 환경 변수를 로드하기 위함

# %% [markdown]
# 1. 환경 변수 Load해서 api_key 가져오고 OpenAI 클라이언트(객체) 초기화

# %%
load_dotenv() 
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %% [markdown]
# 2. DB 초기화 함수 (매 실행 시 DB 폴더를 삭제 후 새로 생성)

# %%
# DB 초기화 함수
def init_db(db_path="./chroma_db"): # 현재 디렉토리 내의 chroma_db폴더 설정
    dbclient = chromadb.PersistentClient(path=db_path) # 지정 경로로 향하는 dbClient 생성
    # rag_collection이라는 데이터 컬렉션(모음집) 만듦
    # get_or_create옵션은 만약 해당 이름 컬렉션이 이미 존재하면 기존 컬렉션 쓰고 아님 만들고
    collection = dbclient.create_collection(name="rag_collection", get_or_create=True)
    return dbclient, collection

# %% [markdown]
# 3. 텍스트 로딩 함수

# %%
# 텍스트 로딩 함수 
def load_text_files(folder_path):
    docs=[] # 텍스트 파일의 (파일명, 내용) 튜플들을 저장할 빈 리스트 생성
    for filename in os.listdir(folder_path): 
		    # 현재 폴더 경로와 파일 이름을 결합하여 파일의 전체 경로를 생성
        file_path = os.path.join(folder_path, filename) 
        if file_path.endswith(".txt"): # .txt 파일들을 처리하게 함
            with open(file_path, "r", encoding="utf-8") as f: # 읽기모드로 열고 인코딩
                text = f.read() # 파일 전체 내용을 읽어서 문자열로 저장
                docs.append((filename, text)) # (파일명, 내용) 튜플을 docs 리스트에 추가
    return docs # 모든 텍스트 파일의 (파일명, 내용) 튜플 리스트를 반환

# %% [markdown]
# 4. 주어진 text를 임베딩 벡터로 변환하는 함수

# %%
# 주어진 text를 임베딩 벡터로 변환하는 함수 
def get_embedding(text, model="text-embedding-3-large"):
		# 여기서 client는 앞서 초기화한 OpenAI 클라이언트
    response = client.embeddings.create(input=[text], model=model)
    embedding = response.data[0].embedding # 응답 객체의 data 리스트에서 embedding 필드 추출
    return embedding

# %% [markdown]
# 5. 원천 데이터 청크 단위로 나누고 overlap 사이즈 조절하는 함수

# %%
# 원천 데이터 청크 단위로 나누고 overlap 사이즈 조절하는 함수
def chunk_text(text, chunk_size=400, chunk_overlap=50):
    chunks = [] # 분할된 텍스트 청크들을 저장할 리스트
    start = 0 # 청크를 시작할 위치를 나타내는 인덱스
    while start < len(text):
        end = start + chunk_size
        chunk = text[start:end] # 텍스트에서 start부터 end까지 부분 문자열을 추출
        chunks.append(chunk) # 추출한 청크를 리스트에 추가
        start = end - chunk_overlap # overlap 적용

        if start < 0: # 음수가 될 수 있으니 예외 처리
            start = 0

        if start >= len(text): # 종료 시그널
            break

    return chunks # 모든 청크가 저장된 리스트를 반환

# %% [markdown]
# 6. 문서로드 -> 청크 나누고 -> 임베딩 생성 후 DB 삽입

# %%
# 문서로드 -> 청크 나누고 -> 임베딩 생성 후 DB 삽입
if __name__ == "__main__":
    # db 초기화
    dbclient, collection = init_db("./chroma_db")

    folder_path = "./source_data" # 데이터 가져다 쓸 경로 지정
    docs = load_text_files(folder_path) # 처리할 문서 데이터 메모리로 불러오기

    doc_id = 0
    for filename, text in docs: 
        chunks = chunk_text(text, chunk_size=400, chunk_overlap=50) # chunking
        for idx, chunk in enumerate(chunks): # 각 청크와 해당 청크의 인덱스 가져옴
            doc_id += 1 # 인덱스 하나씩 증가 시키면서
            embedding = get_embedding(chunk) # 각 청크 임베딩 벡터 생성
            # vectorDB에 다음 정보 추가
            collection.add(
                documents=[chunk], # 실제 청크 text
                embeddings=[embedding], # 생성된 임베딩 벡터
                metadatas=[{"filename": filename, "chunk_index": idx}], # 파일 이름과 청크 인덱스를 포함하는 메타데이터
                ids=[str(doc_id)] # 각 청크의 Unique한 id 저장
                # 이 고유 id를 통해 db에서 업데이트, 삭제등의 작업 가능 
            )
            
    print("모든 문서 벡터DB에 저장 완료")
# Out:
# 모든 문서 벡터DB에 저장 완료
